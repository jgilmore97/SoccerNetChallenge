# %%
# !pip install SoccerNet --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.9/85.9 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 15.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 30.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/soccer_net/CALF/'
# Out:
# /content/drive/MyDrive/soccer_net/CALF

# %%
# !python src/main.py --SoccerNet_path /content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/ --features ResNET_TF2_PCA512.npy --num_features 512 --model_name mha_4_head_1024ffdim_wd_full --model 'hybrid' --batch_size 32 --evaluation_frequency 20 --chunks_per_epoch 18000 --max_epochs 250 --LR 1e-03 --transformer_ff_dim 1056 --num_heads 4
# Out:
# 2024-12-11 03:03:49,062 [MainThread  ] [INFO ]  Starting main function
# 2024-12-11 03:03:49,063 [MainThread  ] [INFO ]  Parameters:
# 2024-12-11 03:03:49,063 [MainThread  ] [INFO ]   SoccerNet_path : /content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/
# 2024-12-11 03:03:49,064 [MainThread  ] [INFO ]         features : ResNET_TF2_PCA512.npy
# 2024-12-11 03:03:49,064 [MainThread  ] [INFO ]       max_epochs : 250
# 2024-12-11 03:03:49,064 [MainThread  ] [INFO ]     load_weights : None
# 2024-12-11 03:03:49,064 [MainThread  ] [INFO ]       model_name : mha_4_head_1024ffdim_wd_full
# 2024-12-11 03:03:49,064 [MainThread  ] [INFO ]        test_only : False
# 2024-12-11 03:03:49,064 [MainThread  ] [INFO ]        challenge : False
# 2024-12-11 03:03:49,064 [MainThread  ] [INFO ]         K_params : None
# 2024-12-11 03:03:49,065 [MainThread  ] [INFO ]     num_features : 512
# 2024-12-11 03:03:49,065 [MainThread  ] [INFO ]  chunks_per_epoch : 18000
# ...

# %%
# !python src/main.py --SoccerNet_path /content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/ --features ResNET_TF2_PCA512.npy --num_features 512 --model_name mha_2head_512ffdim_50 --model 'hybrid' --batch_size 32 --evaluation_frequency 20 --chunks_per_epoch 18000 --max_epochs 50 --LR 1e-03  --subset 50 --transformer_ff_dim 512 --num_heads 2
# Out:
# 2024-12-09 05:21:56,204 [MainThread  ] [INFO ]  Starting main function
# 2024-12-09 05:21:56,205 [MainThread  ] [INFO ]  Parameters:
# 2024-12-09 05:21:56,206 [MainThread  ] [INFO ]   SoccerNet_path : /content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/
# 2024-12-09 05:21:56,207 [MainThread  ] [INFO ]         features : ResNET_TF2_PCA512.npy
# 2024-12-09 05:21:56,207 [MainThread  ] [INFO ]       max_epochs : 50
# 2024-12-09 05:21:56,207 [MainThread  ] [INFO ]     load_weights : None
# 2024-12-09 05:21:56,207 [MainThread  ] [INFO ]       model_name : mha_2head_512ffdim_50
# 2024-12-09 05:21:56,207 [MainThread  ] [INFO ]        test_only : False
# 2024-12-09 05:21:56,208 [MainThread  ] [INFO ]        challenge : False
# 2024-12-09 05:21:56,208 [MainThread  ] [INFO ]         K_params : None
# 2024-12-09 05:21:56,208 [MainThread  ] [INFO ]     num_features : 512
# 2024-12-09 05:21:56,208 [MainThread  ] [INFO ]  chunks_per_epoch : 18000
# ...

# %%
# !python src/main.py --SoccerNet_path /content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/ --features ResNET_TF2_PCA512.npy --num_features 512 --model_name mha_2head_1024ffdim_50 --model 'hybrid' --batch_size 32 --evaluation_frequency 20 --chunks_per_epoch 18000 --max_epochs 50 --LR 1e-03  --subset 50 --transformer_ff_dim 1024 --num_heads 2
# Out:
# 2024-12-09 05:50:55,717 [MainThread  ] [INFO ]  Starting main function
# 2024-12-09 05:50:55,718 [MainThread  ] [INFO ]  Parameters:
# 2024-12-09 05:50:55,719 [MainThread  ] [INFO ]   SoccerNet_path : /content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/
# 2024-12-09 05:50:55,720 [MainThread  ] [INFO ]         features : ResNET_TF2_PCA512.npy
# 2024-12-09 05:50:55,720 [MainThread  ] [INFO ]       max_epochs : 50
# 2024-12-09 05:50:55,720 [MainThread  ] [INFO ]     load_weights : None
# 2024-12-09 05:50:55,720 [MainThread  ] [INFO ]       model_name : mha_2head_1024ffdim_50
# 2024-12-09 05:50:55,720 [MainThread  ] [INFO ]        test_only : False
# 2024-12-09 05:50:55,720 [MainThread  ] [INFO ]        challenge : False
# 2024-12-09 05:50:55,721 [MainThread  ] [INFO ]         K_params : None
# 2024-12-09 05:50:55,721 [MainThread  ] [INFO ]     num_features : 512
# 2024-12-09 05:50:55,721 [MainThread  ] [INFO ]  chunks_per_epoch : 18000
# ...

# %%
# !python src/main.py --SoccerNet_path /content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/ --features ResNET_TF2_PCA512.npy --num_features 512 --model_name mha_4head_256ffdim_50 --model 'hybrid' --batch_size 32 --evaluation_frequency 20 --chunks_per_epoch 18000 --max_epochs 50 --LR 1e-03  --subset 50 --transformer_ff_dim 256 --num_heads 4
# Out:
# 2024-12-09 06:19:15,630 [MainThread  ] [INFO ]  Starting main function
# 2024-12-09 06:19:15,631 [MainThread  ] [INFO ]  Parameters:
# 2024-12-09 06:19:15,631 [MainThread  ] [INFO ]   SoccerNet_path : /content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/
# 2024-12-09 06:19:15,632 [MainThread  ] [INFO ]         features : ResNET_TF2_PCA512.npy
# 2024-12-09 06:19:15,632 [MainThread  ] [INFO ]       max_epochs : 50
# 2024-12-09 06:19:15,632 [MainThread  ] [INFO ]     load_weights : None
# 2024-12-09 06:19:15,632 [MainThread  ] [INFO ]       model_name : mha_4head_256ffdim_50
# 2024-12-09 06:19:15,632 [MainThread  ] [INFO ]        test_only : False
# 2024-12-09 06:19:15,632 [MainThread  ] [INFO ]        challenge : False
# 2024-12-09 06:19:15,632 [MainThread  ] [INFO ]         K_params : None
# 2024-12-09 06:19:15,632 [MainThread  ] [INFO ]     num_features : 512
# 2024-12-09 06:19:15,633 [MainThread  ] [INFO ]  chunks_per_epoch : 18000
# ...

# %%
# !python src/main.py --SoccerNet_path /content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/ --features ResNET_TF2_PCA512.npy --num_features 512 --model_name mha_4head_512ffdim_50 --model 'hybrid' --batch_size 32 --evaluation_frequency 20 --chunks_per_epoch 18000 --max_epochs 50 --LR 1e-03  --subset 50 --transformer_ff_dim 512 --num_heads 4
# Out:
# 2024-12-09 06:48:33,925 [MainThread  ] [INFO ]  Starting main function
# 2024-12-09 06:48:33,926 [MainThread  ] [INFO ]  Parameters:
# 2024-12-09 06:48:33,927 [MainThread  ] [INFO ]   SoccerNet_path : /content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/
# 2024-12-09 06:48:33,927 [MainThread  ] [INFO ]         features : ResNET_TF2_PCA512.npy
# 2024-12-09 06:48:33,927 [MainThread  ] [INFO ]       max_epochs : 50
# 2024-12-09 06:48:33,928 [MainThread  ] [INFO ]     load_weights : None
# 2024-12-09 06:48:33,928 [MainThread  ] [INFO ]       model_name : mha_4head_512ffdim_50
# 2024-12-09 06:48:33,928 [MainThread  ] [INFO ]        test_only : False
# 2024-12-09 06:48:33,928 [MainThread  ] [INFO ]        challenge : False
# 2024-12-09 06:48:33,928 [MainThread  ] [INFO ]         K_params : None
# 2024-12-09 06:48:33,928 [MainThread  ] [INFO ]     num_features : 512
# 2024-12-09 06:48:33,928 [MainThread  ] [INFO ]  chunks_per_epoch : 18000
# ...

# %%
# !python src/main.py --SoccerNet_path /content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/ --features ResNET_TF2_PCA512.npy --num_features 512 --model_name mha_4head_1024ffdim_50 --model 'hybrid' --batch_size 32 --evaluation_frequency 20 --chunks_per_epoch 18000 --max_epochs 50 --LR 1e-03  --subset 50 --transformer_ff_dim 1024 --num_heads 4
# Out:
# 2024-12-09 07:18:26,888 [MainThread  ] [INFO ]  Starting main function
# 2024-12-09 07:18:26,889 [MainThread  ] [INFO ]  Parameters:
# 2024-12-09 07:18:26,891 [MainThread  ] [INFO ]   SoccerNet_path : /content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/
# 2024-12-09 07:18:26,891 [MainThread  ] [INFO ]         features : ResNET_TF2_PCA512.npy
# 2024-12-09 07:18:26,892 [MainThread  ] [INFO ]       max_epochs : 50
# 2024-12-09 07:18:26,892 [MainThread  ] [INFO ]     load_weights : None
# 2024-12-09 07:18:26,892 [MainThread  ] [INFO ]       model_name : mha_4head_1024ffdim_50
# 2024-12-09 07:18:26,892 [MainThread  ] [INFO ]        test_only : False
# 2024-12-09 07:18:26,892 [MainThread  ] [INFO ]        challenge : False
# 2024-12-09 07:18:26,892 [MainThread  ] [INFO ]         K_params : None
# 2024-12-09 07:18:26,892 [MainThread  ] [INFO ]     num_features : 512
# 2024-12-09 07:18:26,892 [MainThread  ] [INFO ]  chunks_per_epoch : 18000
# ...

# %%
# !python src/main.py --SoccerNet_path /content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/ --features ResNET_TF2_PCA512.npy --num_features 512 --model_name mha_8head_256ffdim_50 --model 'hybrid' --batch_size 32 --evaluation_frequency 20 --chunks_per_epoch 18000 --max_epochs 50 --LR 1e-03  --subset 50 --transformer_ff_dim 256 --num_heads 8
# Out:
# 2024-12-09 07:48:24,191 [MainThread  ] [INFO ]  Starting main function
# 2024-12-09 07:48:24,192 [MainThread  ] [INFO ]  Parameters:
# 2024-12-09 07:48:24,193 [MainThread  ] [INFO ]   SoccerNet_path : /content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/
# 2024-12-09 07:48:24,193 [MainThread  ] [INFO ]         features : ResNET_TF2_PCA512.npy
# 2024-12-09 07:48:24,193 [MainThread  ] [INFO ]       max_epochs : 50
# 2024-12-09 07:48:24,193 [MainThread  ] [INFO ]     load_weights : None
# 2024-12-09 07:48:24,194 [MainThread  ] [INFO ]       model_name : mha_8head_256ffdim_50
# 2024-12-09 07:48:24,194 [MainThread  ] [INFO ]        test_only : False
# 2024-12-09 07:48:24,194 [MainThread  ] [INFO ]        challenge : False
# 2024-12-09 07:48:24,194 [MainThread  ] [INFO ]         K_params : None
# 2024-12-09 07:48:24,194 [MainThread  ] [INFO ]     num_features : 512
# 2024-12-09 07:48:24,194 [MainThread  ] [INFO ]  chunks_per_epoch : 18000
# ...

# %%
# !python src/main.py --SoccerNet_path /content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/ --features ResNET_TF2_PCA512.npy --num_features 512 --model_name mha_8head_512ffdim_50 --model 'hybrid' --batch_size 32 --evaluation_frequency 20 --chunks_per_epoch 18000 --max_epochs 50 --LR 1e-03  --subset 50 --transformer_ff_dim 512 --num_heads 8
# Out:
# 2024-12-09 08:17:28,466 [MainThread  ] [INFO ]  Starting main function
# 2024-12-09 08:17:28,467 [MainThread  ] [INFO ]  Parameters:
# 2024-12-09 08:17:28,468 [MainThread  ] [INFO ]   SoccerNet_path : /content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/
# 2024-12-09 08:17:28,468 [MainThread  ] [INFO ]         features : ResNET_TF2_PCA512.npy
# 2024-12-09 08:17:28,468 [MainThread  ] [INFO ]       max_epochs : 50
# 2024-12-09 08:17:28,468 [MainThread  ] [INFO ]     load_weights : None
# 2024-12-09 08:17:28,468 [MainThread  ] [INFO ]       model_name : mha_8head_512ffdim_50
# 2024-12-09 08:17:28,468 [MainThread  ] [INFO ]        test_only : False
# 2024-12-09 08:17:28,468 [MainThread  ] [INFO ]        challenge : False
# 2024-12-09 08:17:28,469 [MainThread  ] [INFO ]         K_params : None
# 2024-12-09 08:17:28,469 [MainThread  ] [INFO ]     num_features : 512
# 2024-12-09 08:17:28,469 [MainThread  ] [INFO ]  chunks_per_epoch : 18000
# ...

# %%
# !python src/main.py --SoccerNet_path /content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/ --features ResNET_TF2_PCA512.npy --num_features 512 --model_name mha_8head_1024ffdim_50 --model 'hybrid' --batch_size 32 --evaluation_frequency 20 --chunks_per_epoch 18000 --max_epochs 50 --LR 1e-03  --subset 50 --transformer_ff_dim 1024 --num_heads 8
# Out:
# 2024-12-09 08:45:46,107 [MainThread  ] [INFO ]  Starting main function
# 2024-12-09 08:45:46,108 [MainThread  ] [INFO ]  Parameters:
# 2024-12-09 08:45:46,108 [MainThread  ] [INFO ]   SoccerNet_path : /content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/
# 2024-12-09 08:45:46,109 [MainThread  ] [INFO ]         features : ResNET_TF2_PCA512.npy
# 2024-12-09 08:45:46,109 [MainThread  ] [INFO ]       max_epochs : 50
# 2024-12-09 08:45:46,109 [MainThread  ] [INFO ]     load_weights : None
# 2024-12-09 08:45:46,109 [MainThread  ] [INFO ]       model_name : mha_8head_1024ffdim_50
# 2024-12-09 08:45:46,109 [MainThread  ] [INFO ]        test_only : False
# 2024-12-09 08:45:46,109 [MainThread  ] [INFO ]        challenge : False
# 2024-12-09 08:45:46,109 [MainThread  ] [INFO ]         K_params : None
# 2024-12-09 08:45:46,109 [MainThread  ] [INFO ]     num_features : 512
# 2024-12-09 08:45:46,109 [MainThread  ] [INFO ]  chunks_per_epoch : 18000
# ...

# %%
# import subprocess

# # Define the hyperparameters to test
# num_heads_values = [2, 4, 8]
# transformer_ff_dims = [256, 512, 1024]

# # Dictionary to store results
# results = {}

# # Loop through all combinations of num_heads and transformer_ff_dim
# for num_heads in num_heads_values:
#     for transformer_ff_dim in transformer_ff_dims:
#         model_name = f"mha_{num_heads}head_{transformer_ff_dim}ffdim"
#         print(f"Running with model_name={model_name}, num_heads={num_heads}, transformer_ff_dim={transformer_ff_dim}")


#         # Run the subprocess with the current parameters
#         result = subprocess.run(
#             ["python", "src/main.py",
#              "--SoccerNet_path", "/content/drive/MyDrive/soccer_net/CALF/src/spotting_ball_2023/",
#              "--features", "ResNET_TF2_PCA512.npy",
#              "--num_features", "512",
#              "--model_name", model_name,
#              "--model", "hybrid",
#              "--batch_size", "32",
#              "--evaluation_frequency", "20",
#              "--chunks_per_epoch", "18000",
#              "--max_epochs", "20",
#              "--LR", "1e-03",
#              "--subset", "20",
#              "--transformer_ff_dim", str(transformer_ff_dim),
#              "--num_heads", str(num_heads)],
#             stdout=subprocess.PIPE,
#             stderr=subprocess.PIPE,
#             text = True
#         )

#         # Extract the result from the script's output
#         float_result = None
#         for line in result.stdout.splitlines():
#           if line.startswith("Average mAP:"):
#               # Extract the float value after "Average mAP:"
#               average_map = float(line.split("Average mAP:")[1].strip())

#         # Store the result in the dictionary
#         if average_map is not None:
#             print(model_name, ': ', average_map)
#             results[model_name] = average_map
#         else:
#             print(f"Warning: No result found for model {model_name}. Check output.")

# # Sort the results by the float value
# sorted_results = dict(sorted(results.items(), key=lambda item: item[1]))

# # Print the sorted results
# print("Sorted Results:")
# for model, result in sorted_results.items():
#     print(f"{model}: {result}")

# # The sorted_results dictionary contains models and their respective results in ascending order.
# Out:
# Running with model_name=mha_2head_256ffdim, num_heads=2, transformer_ff_dim=256
# mha_2head_256ffdim :  0.022930246062202845
# Running with model_name=mha_2head_512ffdim, num_heads=2, transformer_ff_dim=512
# mha_2head_512ffdim :  0.019388552732569498
# Running with model_name=mha_2head_1024ffdim, num_heads=2, transformer_ff_dim=1024
# mha_2head_1024ffdim :  0.019388552732569498
# Running with model_name=mha_4head_256ffdim, num_heads=4, transformer_ff_dim=256
# mha_4head_256ffdim :  0.019388552732569498
# Running with model_name=mha_4head_512ffdim, num_heads=4, transformer_ff_dim=512
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-fda15e1830da> in <cell line: 11>()
#      16
#      17         # Run the subprocess with the current parameters
# ---> 18         result = subprocess.run(
#      19             ["python", "src/main.py",
# ...
